# %%
from mteb import MTEB
from sentence_transformers import SentenceTransformer
# Out:
# /home/imax/AllHomework/Golden-Retriever/.venv/lib/python3.13/site-packages/mteb/tasks/Retrieval/dan/DanFeverRetrieval.py:30: SyntaxWarning: invalid escape sequence '\o'
#   bibtex_citation="""
# /home/imax/AllHomework/Golden-Retriever/.venv/lib/python3.13/site-packages/mteb/tasks/Retrieval/dan/DanFeverRetrieval.py:133: SyntaxWarning: invalid escape sequence '\o'
#   bibtex_citation="""
# /home/imax/AllHomework/Golden-Retriever/.venv/lib/python3.13/site-packages/mteb/tasks/Retrieval/dan/TV2Nordretrieval.py:30: SyntaxWarning: invalid escape sequence '\`'
#   bibtex_citation="""@inproceedings{flansmose-mikkelsen-etal-2022-ddisco,
# /home/imax/AllHomework/Golden-Retriever/.venv/lib/python3.13/site-packages/mteb/tasks/Retrieval/eng/AILACasedocsRetrieval.py:30: SyntaxWarning: invalid escape sequence '\&'
#   bibtex_citation="""@dataset{paheli_bhattacharya_2020_4063986,
# ...
